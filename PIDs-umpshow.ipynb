# %%
import matplotlib.pyplot as plt
import numpy as np
import itertools

def plot(data, title):
    fig, ax = plt.subplots()
    plt.title(title)
    x = list(itertools.accumulate([item[0] for item in data]))
    y = [item[1] for item in data]
    ax.plot(x, y)
    
    ax.axhline(y=0, color='grey')
    ax.set_xlabel("Time (s)")
    ax.set_ylabel("Expected Error (ft)")

# %%
# PID 0.02, 0.1, 0.001
data = [(0.1, -32.81471),(0.1, 24.05871),(0.1, 12.05267),(0.1, -1.436612),(0.1, 11.3877),(0.1, 6.733912),(0.1, 3.128394),(0.1, 4.621482),(0.1, 1.191021),(0.1, 4.93844),(0.1, 0.2948217),(0.1, 2.830866),(0.1, 1.512542),(0.1, 0.1359321),(0.1, 3.114079),(0.1, -0.9975849),(0.1, 1.939397),(0.1, 0.4917627),(0.1, -0.1221995),(0.1, 2.11955),(0.1, -1.163195),(0.1, 1.348525),(0.1, 0.2057232),(0.1, -0.2958238),(0.1, 1.527478),(0.1, -0.9318092),(0.1, 0.8974891),(0.1, 0.1744552),(0.1, -0.390125),(0.1, 1.091577),(0.1, -0.6019866),(0.1, 0.5573649),(0.1, 0.2102366),(0.1, -0.370845),(0.1, 0.7076885),(0.1, -0.2926979),(0.1, 0.3123185),(0.1, 0.2230666),(0.1, -0.2372057),(0.1, 0.3845993),(0.1, -0.06367692),(0.1, 0.1477938),(0.1, 0.16423),(0.1, -0.01379779),(0.1, -0.234028)]
t = "P=.02, I=0.1, D=0.001"
plot(data, t)

# %%
# PID 0.5, 0 0
data = [(0.1, -26.05227),(0.1, 23.68098),(0.1, 10.18441),(0.1, -31.7976),(0.1, 18.11229),(0.1, 10.09962),(0.1, -32.19078),(0.1, 13.96143),(0.1, 5.651821),(0.1, -17.75565),(0.1, 16.0931),(0.1, 8.178492),(0.1, -21.27078),(0.1, 14.89117),(0.1, 9.143933),(0.1, -27.00138),(0.1, 12.05643),(0.1, 4.793384),(0.1, -16.43629),(0.1, 11.20691),(0.1, 4.909173),(0.1, -12.6653),(0.1, 10.13986),(0.1, 6.241566),(0.1, -17.86362),(0.1, 8.15064),(0.1, 3.849164),(0.1, -12.99124),(0.1, 6.354807),(0.1, 2.225542),(0.1, -6.829577),(0.1, 5.762872),(0.1, 3.442048),(0.1, -8.846025),(0.1, 4.007292),(0.1, 2.356131),(0.1, -7.667204),(0.1, 2.383161),(0.1, 0.832793),(0.1, -0.4135143),(0.1, 0.3361801),(0.1, 0.9777915),(0.1, 0.4417817),(0.1, 0.2166301),(0.1, -0.4746226)]
title = "P = 0.5 (no I or D)"
plot(data, title)

# %%
data = [(0.1, -32.81247),(0.1, 12.55438),(0.1, 19.63387),(0.1, 15.23677),(0.1, 14.10623),(0.1, 5.44695),(0.1, 5.268539),(0.1, 2.272765),(0.1, 0.7132647),(0.1, 3.106276),(0.1, -1.291595),(0.1, 1.821525),(0.1, 0.05393953),(0.1, -0.3564747),(0.1, 1.932398),(0.1, -1.514929),(0.1, 1.155525),(0.1, -0.06056425),(0.1, -0.65666),(0.1, 1.475016),(0.1, -1.203999),(0.1, 0.7885976),(0.1, 0.06813703),(0.1, -0.7795649),(0.1, 1.138921),(0.1, -0.8453428),(0.1, 0.5168132),(0.1, 0.1888499),(0.1, -0.7375487),(0.1, 0.8097245),(0.1, -0.5380359),(0.1, 0.304211),(0.1, 0.2462161),(0.1, -0.6078843),(0.1, 0.5435928),(0.1, -0.3041746),(0.1, 0.1391883),(0.1, 0.2226297),(0.1, -0.3951379),(0.1, 0.2817587),(0.1, -0.109257),(0.1, 0.02449758),(0.1, 0.1102804),(0.1, -0.1091819),(0.1, -0.2075876)]
title = "I = 0.1 (no P or D)"
plot(data, title)

# %%
data = [(0.1, -32.82925),(0.1, 23.8231),(0.1, 11.42395),(0.1, 15.94258),(0.1, 12.98793),(0.1, 16.51898),(0.1, 12.96219),(0.1, 16.0325),(0.1, 12.98507),(0.1, 16.6819),(0.1, 12.71412),(0.1, 16.26886),(0.1, 12.86561),(0.1, 16.76624),(0.1, 12.56629),(0.1, 16.45728),(0.1, 12.74174),(0.1, 16.91119),(0.1, 12.42056),(0.1, 16.69747),(0.1, 12.56288),(0.1, 16.97966),(0.1, 12.35714),(0.1, 16.79312),(0.1, 12.45833),(0.1, 17.01348),(0.1, 12.31259),(0.1, 16.84415),(0.1, 12.45771),(0.1, 16.95487),(0.1, 12.42359),(0.1, 16.69165),(0.1, 12.68436),(0.1, 16.63219),(0.1, 12.85504),(0.1, 16.15708),(0.1, 13.22469),(0.1, 14.94013)]
title = "P = 0.5, D = 0.5 (no I)"
plot(data, title)

# %%
data = [(0.1001297, -57.59414),(0.1097152, 23.00299),(0.1069303, 34.77521),(0.1000352, 17.96777),(0.1088369, -29.91735),(0.1076954, 21.8539),(0.1000964, 5.358747),(0.1090207, -26.95758),(0.1074764, 19.44218),(0.1002714, 7.942365),(0.1254477, -15.3334),(0.1076996, 9.916083),(0.1185908, 2.960839),(0.1147959, -4.116003),(0.1139906, -5.837043),(0.102724, 8.54575),(0.116588, 1.97266),(0.1086842, -4.945599),(0.1080991, 1.191119),(0.1164048, 1.78948),(0.1096251, -5.249084),(0.1070676, 5.095612),(0.1002026, -0.3096144),(0.1097152, -3.389574),(0.1069085, 3.519994),(0.1165727, -0.4000016),(0.1036716, 2.039323),(0.1130112, -3.035217),(0.1004605, 0.06464753),(0.1029354, 0.8974753),(0.1136727, -0.9146018),(0.1161993, 0.2439663),(0.1004147, -1.377265),(0.1163888, 1.348667),(0.1000121, -0.3759562),(0.1165676, 0.3640392),(0.1000835, -0.1251685),(0.1167346, 0.0789189),(0.1165468, -0.008023089),(0.1132508, -0.4734123),(0.1109626, -0.07533939),(0.0174936, -0.4168239)]
title = "I=0.5 (no P or D)"
plot(data, title)
